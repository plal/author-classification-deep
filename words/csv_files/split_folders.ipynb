# %%
import pandas as pd
# Out:
# /home/pedro2/anaconda3/envs/fastai/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pedro2/anaconda3/envs/fastai/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_csv('all.csv')
c03 = data[:4366]
g06 = data[4367:]

# %%
c03
# Out:
#                    files authors
# 0     c03-000a-00-00.png    c03a
# 1     c03-000a-00-01.png    c03a
# 2     c03-000a-00-02.png    c03a
# 3     c03-000a-00-03.png    c03a
# 4     c03-000a-00-04.png    c03a
# 5     c03-000a-00-05.png    c03a
# 6     c03-000a-00-06.png    c03a
# 7     c03-000a-01-00.png    c03a
# 8     c03-000a-01-01.png    c03a
# 9     c03-000a-01-02.png    c03a
# 10    c03-000a-01-03.png    c03a
# 11    c03-000a-01-04.png    c03a
# 12    c03-000a-01-05.png    c03a
# 13    c03-000a-01-06.png    c03a
# 14    c03-000a-01-07.png    c03a
# 15    c03-000a-01-08.png    c03a
# 16    c03-000a-02-00.png    c03a
# 17    c03-000a-02-01.png    c03a
# 18    c03-000a-02-02.png    c03a
# 19    c03-000a-02-03.png    c03a
# 20    c03-000a-02-04.png    c03a
# 21    c03-000a-02-05.png    c03a
# 22    c03-000a-02-06.png    c03a
# 23    c03-000a-02-07.png    c03a
# 24    c03-000a-03-00.png    c03a
# 25    c03-000a-03-01.png    c03a
# 26    c03-000a-03-02.png    c03a
# ...

# %%
g06
# Out:
#                     files authors
# 4367   g06-011a-00-01.png    g06a
# 4368   g06-011a-00-02.png    g06a
# 4369   g06-011a-00-03.png    g06a
# 4370   g06-011a-00-04.png    g06a
# 4371   g06-011a-00-05.png    g06a
# 4372   g06-011a-00-06.png    g06a
# 4373   g06-011a-00-07.png    g06a
# 4374   g06-011a-00-08.png    g06a
# 4375   g06-011a-00-09.png    g06a
# 4376   g06-011a-01-00.png    g06a
# 4377   g06-011a-01-01.png    g06a
# 4378   g06-011a-01-02.png    g06a
# 4379   g06-011a-01-03.png    g06a
# 4380   g06-011a-01-04.png    g06a
# 4381   g06-011a-01-05.png    g06a
# 4382   g06-011a-01-06.png    g06a
# 4383   g06-011a-01-07.png    g06a
# 4384   g06-011a-01-08.png    g06a
# 4385   g06-011a-01-09.png    g06a
# 4386   g06-011a-02-00.png    g06a
# 4387   g06-011a-02-01.png    g06a
# 4388   g06-011a-02-02.png    g06a
# 4389   g06-011a-02-03.png    g06a
# 4390   g06-011a-02-04.png    g06a
# 4391   g06-011a-02-05.png    g06a
# 4392   g06-011a-02-06.png    g06a
# ...

# %%
c03.to_csv('c03.csv', index=False)
g06.to_csv("g06.csv", index=False)
